# %%
import pandas as pd
import os
import glob

# Base directory for the census data (adjusted for notebook path)
base_dir = '../data/raw/inegi_census'

# Find all CSV files across the 32 states
csv_pattern = os.path.join(base_dir, 'ageb_mza_urbana_*_cpv2020', 'conjunto_de_datos', 'conjunto_de_datos_ageb_urbana_*_cpv2020.csv')
csv_files = glob.glob(csv_pattern)

print(f"Found {len(csv_files)} CSV files (should be 32).")

# Initialize empty list for filtered DataFrames and a list for failed files
ageb_dfs = []
failed_files = []

# Loop through each CSV
for csv_path in csv_files:
    entity_code = os.path.basename(csv_path).split('_')[-2]  # Extract ENT code, e.g., '01' (fixed from -3 to -2)
    print(f"\nProcessing: {os.path.basename(csv_path)} (Entity {entity_code})")
    
    try:
        # Load CSV (handle UTF-8 BOM; try latin-1 if UTF-8 fails for accented chars)
        try:
            df = pd.read_csv(csv_path, encoding='utf-8-sig', low_memory=False)
        except UnicodeDecodeError:
            print(f"  UTF-8 failed—trying latin-1 for accents.")
            df = pd.read_csv(csv_path, encoding='latin-1', low_memory=False)
        
        # Debug: Check unique NOM_LOC values (first 10 to avoid spam)
        unique_nom_loc = df['NOM_LOC'].unique()[:10]
        print(f"  Unique NOM_LOC sample: {unique_nom_loc}")
        
        # Check if 'Total AGEB urbana' exists
        if 'Total AGEB urbana' in df['NOM_LOC'].values:
            # Filter for rows where NOM_LOC == 'Total AGEB urbana'
            ageb_totals = df[df['NOM_LOC'] == 'Total AGEB urbana'].copy()
            ageb_dfs.append(ageb_totals)
            print(f"  Found and added {len(ageb_totals)} matching rows.")
        else:
            print(f"  'Total AGEB urbana' NOT found in NOM_LOC—skipping this file.")
            failed_files.append((entity_code, csv_path, unique_nom_loc))
            
    except Exception as e:
        print(f"  Error loading file: {e}")
        failed_files.append((entity_code, csv_path, "Load error"))

# Report on failures
print(f"\n=== LOOP SUMMARY ===")
print(f"Successfully processed files with matches: {len(ageb_dfs)}")
if failed_files:
    print(f"\nFiles that broke the filter ({len(failed_files)}):")
    for code, path, sample in failed_files[:5]:  # Show first 5
        print(f"  - Entity {code}: {os.path.basename(path)} | Sample NOM_LOC: {sample}")
    if len(failed_files) > 5:
        print(f"  ... and {len(failed_files) - 5} more.")

# Attempt concat if any matches
if ageb_dfs:
    national_ageb = pd.concat(ageb_dfs, ignore_index=True)
    print(f"\nNational filtered shape: {national_ageb.shape}")
    print("First 5 rows:")
    print(national_ageb[['ENTIDAD', 'NOM_MUN', 'NOM_LOC', 'AGEB', 'MZA', 'POBTOT']].head())
    
    # Process AGEB ID: Standardize for merging (pad to 4 chars, ensure string)
    national_ageb['AGEB'] = national_ageb['AGEB'].astype(str).str.zfill(4)
    
    # Optional: Construct full CVEGEO (ENT + MUN + LOC + AGEB, padded) for advanced joins
    national_ageb['ENT'] = national_ageb['ENTIDAD'].astype(str).str.zfill(2)
    national_ageb['MUN'] = national_ageb['MUN'].astype(str).str.zfill(3)
    national_ageb['LOC'] = national_ageb['LOC'].astype(str).str.zfill(4)  # If LOC varies; drop if not used
    national_ageb['CVEGEO'] = (national_ageb['ENT'] + national_ageb['MUN'] + national_ageb['LOC'] + national_ageb['AGEB'])
    
    # Quick check: Unique AGEBs, sample
    print(f"\nUnique AGEBs after padding: {national_ageb['AGEB'].nunique()}")
    print("Sample with processed IDs:")
    print(national_ageb[['ENTIDAD', 'MUN', 'AGEB', 'CVEGEO', 'POBTOT']].head())
    
    # Save the national DF for next steps (optional, but recommended for efficiency)
    national_ageb.to_parquet('../data/processed/ageb_total/national_ageb.parquet', index=False)
    print("\nSaved as 'national_ageb.parquet' in processed/.")
else:
    print("\nNo matching files found—check if 'Total AGEB urbana' is the exact string (case-sensitive?).")
    print("Suggestion: Run df['NOM_LOC'].value_counts() on one file to inspect all unique values.")
# Out:
# Found 32 CSV files (should be 32).
#
# Processing: conjunto_de_datos_ageb_urbana_10_cpv2020.csv (Entity 10)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Canatlán' 'Canelas'
#  'Coneto de Comonfort' 'Cuencamé de Ceniceros' 'Cuauhtémoc' 'Velardeña']
#   Found and added 1890 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_19_cpv2020.csv (Entity 19)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Abasolo' 'Agualeguas'
#  'Los Aldamas' 'Ciudad de Allende' 'Anáhuac' 'Ciudad Apodaca']
#   Found and added 2765 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_09_cpv2020.csv (Entity 09)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Azcapotzalco'
#  'Coyoacán' 'Cuajimalpa de Morelos' 'San Lorenzo Acopilco'
#  'Gustavo A. Madero' 'Iztacalco']
#   Found and added 2433 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_26_cpv2020.csv (Entity 26)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Aconchi'
#  'Agua Prieta' 'Álamos' 'Altar' 'Arivechi' 'Arizpe']
#   Found and added 3206 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_08_cpv2020.csv (Entity 08)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Miguel Ahumada'
#  'Juan Aldama' 'Valle de Ignacio Allende' 'Santa Eulalia'
#  'Ninguno [CERESO]' 'Ascensión']
#   Found and added 2891 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_18_cpv2020.csv (Entity 18)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acaponeta'
#  'Ahuacatlán' 'Amatlán de Cañas' 'Compostela' 'La Peñita de Jaltemba'
#  'Rincón de Guayabitos']
#   Found and added 832 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_27_cpv2020.csv (Entity 27)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Balancán'
#  'El Triunfo' 'Cárdenas' 'Poblado C-11 José María Morelos y Pavón'
#  'Poblado C-15 Adolfo López Mateos'
#  'Arroyo Hondo 1ra. Sección (Santa Teresa A)']
#   Found and added 610 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_11_cpv2020.csv (Entity 11)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Abasolo'
#  'Rancho Nuevo de la Cruz' 'Acámbaro' 'Chupícuaro (Nuevo Chupícuaro)'
#  'Irámuco' 'Parácuaro']
#   Found and added 3718 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_01_cpv2020.csv (Entity 01)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Aguascalientes'
#  'Jaltomate' 'General José María Morelos y Pavón (Cañada Honda)'
#  'Norias de Ojocaliente' 'Norias del Paso Hondo' 'San Antonio de Peñuelas']
#   Found and added 480 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_25_cpv2020.csv (Entity 25)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Los Mochis' 'Ahome'
#  'Bagojo Colectivo' 'Cerrillos (Campo 35)' 'Cohuibampo' 'El Colorado']
#   Found and added 2132 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_03_cpv2020.csv (Entity 03)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Ciudad Constitución'
#  'Ciudad Insurgentes' 'Puerto San Carlos' 'Santa Rosalía' 'Bahía Tortugas'
#  'Guerrero Negro']
#   Found and added 939 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_13_cpv2020.csv (Entity 13)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acatlán'
#  'Acaxochitlán' 'Los Reyes' 'San Mateo' 'Santa Ana Tzacuala'
#  'Tepepa (Santiago Tepepa)']
#   Found and added 1441 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_12_cpv2020.csv (Entity 12)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acapulco de Juárez'
#  'Amatillo' 'Kilómetro 30' 'Los Órganos de Juan R. Escudero'
#  'San Isidro Gallinero (El Gallinero)' 'San Pedro las Playas']
#   Found and added 2410 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_02_cpv2020.csv (Entity 02)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Ensenada'
#  'Francisco Zarco (Valle de Guadalupe)'
#  'Rodolfo Sánchez Taboada (Maneadero)'
#  'Ejido Punta Colnett (Punta Colonet)'
#  'Real del Castillo Nuevo (Ojos Negros)' 'San Vicente']
#   Found and added 1782 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_24_cpv2020.csv (Entity 24)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana'
#  'Ahualulco del Sonido 13' 'Alaquines' 'Aquismón' 'Tampate'
#  'Armadillo de los Infante' 'Cárdenas']
#   Found and added 1575 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_21_cpv2020.csv (Entity 21)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acajete'
#  'La Magdalena Tetela Morelos' 'San Agustín Tlaxco'
#  'San Jerónimo Ocotitlán' 'Santa Isabel Tepetzala'
#  'Santa María Nenetzintla']
#   Found and added 2503 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_31_cpv2020.csv (Entity 31)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Abalá' 'Uayalceh'
#  'Acanceh' 'Akil' 'Baca' 'Bokobá']
#   Found and added 1532 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_28_cpv2020.csv (Entity 28)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Abasolo'
#  'Guadalupe Victoria' 'Aldama' 'Altamira' 'Cuauhtémoc' 'Miramar']
#   Found and added 2440 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_07_cpv2020.csv (Entity 07)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acacoyagua' 'Acala'
#  'Acapetahua' 'Soconusco' 'Altamirano' 'Amatán']
#   Found and added 1925 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_17_cpv2020.csv (Entity 17)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Amacuzac'
#  'San Gabriel las Palmas' 'Atlatlahucan'
#  'Fraccionamiento Lomas de Cocoyoc' 'Axochiapan' 'Atlacahualoya']
#   Found and added 1021 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_29_cpv2020.csv (Entity 29)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Amaxac de Guerrero'
#  'Apetatitlán' 'Belén Atzitzimititlán' 'San Matías Tepetomatitlán'
#  'Tecolotla' 'Tlatempan']
#   Found and added 668 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_16_cpv2020.csv (Entity 16)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acuitzio del Canje'
#  'Aguililla' 'Bonifacio Moreno (El Aguaje)' 'Álvaro Obregón'
#  'Angamacutiro de la Unión' 'Mineral de Angangueo']
#   Found and added 2842 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_06_cpv2020.csv (Entity 06)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Ciudad de Armería'
#  'Cofradía de Juárez' 'Rincón de López' 'Colima' 'Comala' 'Suchitlán']
#   Found and added 548 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_30_cpv2020.csv (Entity 30)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acajete' 'Acatlán'
#  'Acayucan' 'Corral Nuevo' 'Dehesa' 'Actopan']
#   Found and added 3356 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_20_cpv2020.csv (Entity 20)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Abejones'
#  'Acatlán de Pérez Figueroa' 'Cerro Mojarra' 'Tetela' 'Vicente Camalote'
#  'Asunción Cacalotepec']
#   Found and added 2666 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_04_cpv2020.csv (Entity 04)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Calkiní' 'Bacabchén'
#  'Bécal' 'Dzitbalché' 'Nunkiní' 'San Francisco de Campeche']
#   Found and added 472 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_14_cpv2020.csv (Entity 14)
#   UTF-8 failed—trying latin-1 for accents.
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Acatic'
#  'El Refugio (Paredones)' 'Acatlán de Juárez' 'Bellavista'
#  'El Plan (El Cerrito)' 'Ahualulco de Mercado']
#   Found and added 4894 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_22_cpv2020.csv (Entity 22)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Amealco de Bonfil'
#  'San Ildefonso Tultepec (Centro)' 'Pinal de Amoles' 'Arroyo Seco'
#  'Purísima de Arista' 'Cadereyta de Montes']
#   Found and added 891 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_32_cpv2020.csv (Entity 32)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Apozol' 'Apulco'
#  'Atolinga' 'Florencia' 'Víctor Rosales' 'Ramón López Velarde (Toribio)']
#   Found and added 2068 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_23_cpv2020.csv (Entity 23)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Cozumel'
#  'Felipe Carrillo Puerto' 'Chunhuhub' 'Señor' 'Tepich' 'Tihosuco']
#   Found and added 1035 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_15_cpv2020.csv (Entity 15)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana'
#  'Villa de Acambay de Ruíz Castañeda' 'Pueblo Nuevo'
#  'Acolman de Nezahualcóyotl' 'San Bartolo' 'San Marcos Nepantla'
#  'San Pedro Tepetitlán']
#   Found and added 4465 matching rows.
#
# Processing: conjunto_de_datos_ageb_urbana_05_cpv2020.csv (Entity 05)
#   Unique NOM_LOC sample: ['Total de la entidad' 'Total del municipio'
#  'Total de la localidad urbana' 'Total AGEB urbana' 'Abasolo'
#  'Ciudad Acuña' 'Allende' 'Arteaga' 'San Antonio de las Alazanas'
#  'Candela']
#   Found and added 1883 matching rows.
#
# === LOOP SUMMARY ===
# Successfully processed files with matches: 32
#
# National filtered shape: (64313, 230)
# First 5 rows:
#    ENTIDAD   NOM_MUN            NOM_LOC  AGEB  MZA  POBTOT
# 0       10  Canatlán  Total AGEB urbana  0054    0     572
# 1       10  Canatlán  Total AGEB urbana  0069    0     674
# 2       10  Canatlán  Total AGEB urbana  0088    0     995
# 3       10  Canatlán  Total AGEB urbana  0092    0     902
# 4       10  Canatlán  Total AGEB urbana  0105    0    1644
#
# Unique AGEBs after padding: 8002
# Sample with processed IDs:
#    ENTIDAD  MUN  AGEB         CVEGEO  POBTOT
# 0       10  001  0054  1000100010054     572
# 1       10  001  0069  1000100010069     674
# 2       10  001  0088  1000100010088     995
# 3       10  001  0092  1000100010092     902
# 4       10  001  0105  1000100010105    1644
#
# Saved as 'national_ageb.parquet' in processed/.
